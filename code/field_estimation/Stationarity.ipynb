# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import pytz
import argparse
# import jax.numpy as jnp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from geopy import distance
import datetime
import tilemapbase
from copy import deepcopy
import pickle as pkl
from PIL import Image
import skimage.measure
import math
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
os.environ['PYTHONWARNINGS']='ignore'
import hyperopt
from joblib import Parallel, delayed
import random
random.seed(42)
import scipy
import torch
from pykrige.ok import OrdinaryKriging
from pykrige.ok3d import OrdinaryKriging3D
from pykrige.uk import UniversalKriging
from sklearn.model_selection import train_test_split
from scipy.interpolate import CubicSpline

# %% [markdown]
# # Data Loading

# %%
source = 'combined'
sensor = 'pm25'
res_time = '1H'
filepath_root = '/scratch/ab9738/hidden_hotspots/'

# %%
filepath_data_kai = filepath_root+'data/kaiterra/kaiterra_fieldeggid_{}_current_panel.csv'.format(res_time)
filepath_data_gov = filepath_root+'data/govdata/govdata_{}_current.csv'.format(res_time)
filepath_locs_kai = filepath_root+'data/kaiterra/kaiterra_locations.csv'
filepath_locs_gov = filepath_root+'data/govdata/govdata_locations.csv'

locs_kai = pd.read_csv(filepath_locs_kai, index_col=[0])
locs_kai['Type'] = 'Kaiterra'
locs_gov = pd.read_csv(filepath_locs_gov, index_col=[0])
locs_gov['Type'] = 'Govt'
locs = pd.merge(locs_kai, locs_gov, how='outer',\
                on=['Monitor ID', 'Latitude', 'Longitude', 'Location', 'Type'], copy=False)
data_kai = pd.read_csv(filepath_data_kai, index_col=[0,1], parse_dates=True)[sensor]
data_gov = pd.read_csv(filepath_data_gov, index_col=[0,1], parse_dates=True)[sensor]
data = pd.concat([data_kai, data_gov], axis=0, copy=False)
data.replace(0,np.nan,inplace=True)

start_dt = data.index.levels[1][0]
end_dt = data.index.levels[1][-1]

if start_dt.tzname != 'IST':
        if start_dt.tzinfo is None:
            start_dt = start_dt.tz_localize('UTC')
        start_dt = start_dt.tz_convert(pytz.FixedOffset(330))
    
if end_dt.tzname != 'IST':
    if end_dt.tzinfo is None: 
        end_dt = end_dt.tz_localize('UTC')
    end_dt = end_dt.tz_convert(pytz.FixedOffset(330))

# now, filter through the start and end dates
data.sort_index(inplace=True)
data = data.loc[(slice(None), slice(start_dt, end_dt))]

if(source=='govdata'):
    df = data_gov.unstack(level=0)
elif(source=='kaiterra'):
    df = data_kai.unstack(level=0)
else:
    df = data.unstack(level=0)
distances = pd.read_csv('/scratch/ab9738/hidden_hotspots/data/combined_distances.csv', index_col=[0])
distances = distances.loc[df.columns, df.columns]
distances[distances == 0] = np.nan

# %%
from statsmodels.tsa.stattools import adfuller

# %%
for col in df.columns:
    X = df[col].dropna().values
    result = adfuller(X)
    # print('ADF Statistic: %f' % result[0])
    print('sensor:{}, p-value: {}'.format(col,result[1]))
    # print('Critical Values:')
    # for key, value in result[4].items():
    #     print('\t%s: %.3f' % (key, value))
# Out:
# sensor:113E, p-value: 9.635986211871643e-06
# sensor:1FD7, p-value: 0.0421570029513192
# sensor:20CA, p-value: 9.511182423179522e-05
# sensor:2E9C, p-value: 0.04375856614360218
# sensor:3ACF, p-value: 0.976760910009257
# sensor:498F, p-value: 0.0012742462166559585
# sensor:4BE7, p-value: 1.1479493083420188e-06
# sensor:56C3, p-value: 0.00014606552718580303
# sensor:5D7A, p-value: 1.526560503750724e-05
# sensor:603A, p-value: 0.0006723684866630278
# sensor:72CA, p-value: 2.995599847820941e-06
# sensor:8E2A, p-value: 1.985092878650329e-06
# sensor:91B8, p-value: 0.002052228792883589
# sensor:97D7, p-value: 0.0003981522968403064
# sensor:A838, p-value: 0.0008380210760562134
# sensor:A9BE, p-value: 7.482885838889009e-06
# sensor:AnandVihar_DPCC, p-value: 3.975582214271166e-10
# sensor:AshokVihar_DPCC, p-value: 1.529669793185092e-09
# sensor:AyaNagar_IMD, p-value: 4.5200002747668913e-10
# sensor:BB4A, p-value: 0.008776908107393585
# sensor:BC46, p-value: 0.00012571323418282014
# sensor:BFDC, p-value: 0.39986426386592117
# sensor:BurariCrossing_IMD, p-value: 6.164432828966123e-09
# sensor:C0A7, p-value: 1.63123486214191e-05
# sensor:CBC7, p-value: 0.00020262425667858468
# sensor:CRRIMathuraRoad_IMD, p-value: 8.020531787197066e-09
# sensor:D804, p-value: 0.00026393400312480566
# sensor:DF07, p-value: 0.0004610770684849006
# sensor:DKSSR_DPCC, p-value: 2.0708849824252844e-07
# sensor:DTU_CPCB, p-value: 3.979592828897679e-08
# sensor:DwarkaSector8_DPCC, p-value: 6.739731944352724e-09
# sensor:E1F8, p-value: 0.009658166284182606
# sensor:E47A, p-value: 0.0375408620774649
# sensor:E486, p-value: 8.976155749427991e-06
# sensor:E8E4, p-value: 6.966230910908324e-05
# sensor:EAC8, p-value: 1.713154647518893e-05
# sensor:IGIAirport_IMD, p-value: 3.4324491150234016e-08
# sensor:IHBAS_CPCB, p-value: 9.869894433322248e-13
# sensor:ITO_CPCB, p-value: 2.243075069625779e-10
# sensor:JNS_DPCC, p-value: 2.4986726236409745e-07
# sensor:Jahangirpuri_DPCC, p-value: 1.055665264509344e-06
# sensor:LodhiRoad_IMD, p-value: 9.45496526563182e-10
# sensor:MDCNS_DPCC, p-value: 3.9036622070499284e-09
# sensor:MandirMarg_DPCC, p-value: 2.5046013704686846e-08
# sensor:Mundaka_DPCC, p-value: 1.3501064073307706e-07
# sensor:NSIT_CPCB, p-value: 4.914200335371177e-12
# sensor:NehruNagar_DPCC, p-value: 8.18253474296139e-07
# sensor:OkhlaPhase2_DPCC, p-value: 1.669222614935562e-08
# sensor:Patparganj_DPCC, p-value: 4.289438735273803e-08
# sensor:PunjabiBagh_DPCC, p-value: 9.408487244751509e-12
# sensor:Pusa_DPCC, p-value: 7.39534387958573e-06
# sensor:Pusa_IMD, p-value: 1.8010284100061645e-08
# sensor:RKPuram_DPCC, p-value: 3.7366399359755774e-08
# sensor:Rohini_DPCC, p-value: 5.90537130965561e-08
# sensor:Shadipur_CPCB, p-value: 1.0144951713962455e-10
# sensor:Sirifort_CPCB, p-value: 1.866041813123077e-08
# sensor:SoniaVihar_DPCC, p-value: 1.350141099130821e-08
# sensor:SriAurobindoMarg_DPCC, p-value: 4.97534773788188e-07
# sensor:VivekVihar_DPCC, p-value: 8.09235475173689e-11
# sensor:Wazirpur_DPCC, p-value: 5.370447713277282e-09

# %%
df = np.log(df)

# %%
for col in df.columns:
    X = df[col].dropna().values
    result = adfuller(X)
    # print('ADF Statistic: %f' % result[0])
    print('sensor:{}, p-value: {}'.format(col,result[1]))
    # print('Critical Values:')
    # for key, value in result[4].items():
    #     print('\t%s: %.3f' % (key, value))
# Out:
# sensor:113E, p-value: 7.518600145906119e-05
# sensor:1FD7, p-value: 0.009257643873516842
# sensor:20CA, p-value: 0.0014838358381846404
# sensor:2E9C, p-value: 0.027950347793309883
# sensor:3ACF, p-value: 0.164435070729053
# sensor:498F, p-value: 0.028944669019323806
# sensor:4BE7, p-value: 3.8549335500937e-05
# sensor:56C3, p-value: 0.0002058104820923644
# sensor:5D7A, p-value: 3.052555674864269e-05
# sensor:603A, p-value: 0.0006820825985258879
# sensor:72CA, p-value: 9.388407736664602e-05
# sensor:8E2A, p-value: 0.00015290437912993712
# sensor:91B8, p-value: 0.005130190710158837
# sensor:97D7, p-value: 0.0006518173663447429
# sensor:A838, p-value: 0.0005145542215528568
# sensor:A9BE, p-value: 1.874468909237184e-05
# sensor:AnandVihar_DPCC, p-value: 1.5067080808350507e-07
# sensor:AshokVihar_DPCC, p-value: 1.0126585850327229e-06
# sensor:AyaNagar_IMD, p-value: 1.096700074965333e-09
# sensor:BB4A, p-value: 0.1336447482415417
# sensor:BC46, p-value: 0.0001826333036101168
# sensor:BFDC, p-value: 0.004439840726677537
# sensor:BurariCrossing_IMD, p-value: 3.9415347548720914e-07
# sensor:C0A7, p-value: 2.8879431665305303e-05
# sensor:CBC7, p-value: 1.3871649847048951e-05
# sensor:CRRIMathuraRoad_IMD, p-value: 1.863562862411645e-08
# sensor:D804, p-value: 0.0004294208991454277
# sensor:DF07, p-value: 0.0007035964067914588
# sensor:DKSSR_DPCC, p-value: 2.970384956681705e-07
# sensor:DTU_CPCB, p-value: 5.792148009293072e-07
# sensor:DwarkaSector8_DPCC, p-value: 2.2640717143402043e-07
# sensor:E1F8, p-value: 0.017653768056212348
# sensor:E47A, p-value: 0.005791892140975626
# sensor:E486, p-value: 4.620482182325921e-05
# sensor:E8E4, p-value: 0.000287390911861073
# sensor:EAC8, p-value: 0.00011655461375489625
# sensor:IGIAirport_IMD, p-value: 1.0338394983560082e-07
# sensor:IHBAS_CPCB, p-value: 1.8582445005878835e-07
# sensor:ITO_CPCB, p-value: 7.531041720149182e-08
# sensor:JNS_DPCC, p-value: 1.4229152645717598e-06
# sensor:Jahangirpuri_DPCC, p-value: 2.2027843638571885e-06
# sensor:LodhiRoad_IMD, p-value: 1.719315406326641e-09
# sensor:MDCNS_DPCC, p-value: 2.1107315979551714e-07
# sensor:MandirMarg_DPCC, p-value: 1.6128859519949815e-07
# sensor:Mundaka_DPCC, p-value: 2.4759133380497007e-06
# sensor:NSIT_CPCB, p-value: 3.2804674934105813e-06
# sensor:NehruNagar_DPCC, p-value: 5.068130814762466e-06
# sensor:OkhlaPhase2_DPCC, p-value: 1.6440258522586653e-06
# sensor:Patparganj_DPCC, p-value: 1.0794243909331547e-07
# sensor:PunjabiBagh_DPCC, p-value: 9.518531086392368e-09
# sensor:Pusa_DPCC, p-value: 6.126833746309428e-06
# sensor:Pusa_IMD, p-value: 3.9832248413400394e-08
# sensor:RKPuram_DPCC, p-value: 5.732855189080743e-07
# sensor:Rohini_DPCC, p-value: 2.5409639289129824e-06
# sensor:Shadipur_CPCB, p-value: 2.2129405117996844e-06
# sensor:Sirifort_CPCB, p-value: 2.733042018741775e-07
# sensor:SoniaVihar_DPCC, p-value: 3.655451786344904e-07
# sensor:SriAurobindoMarg_DPCC, p-value: 4.112525325594175e-06
# sensor:VivekVihar_DPCC, p-value: 3.8647565069722015e-09
# sensor:Wazirpur_DPCC, p-value: 2.1525586149053473e-06

# %%
sens = np.log(data).to_frame().reset_index()

sens['hour_of_day'] = sens['timestamp_round'].apply(lambda x: x.hour)

spline = sens.groupby(['field_egg_id', 'hour_of_day']).mean()['pm25'].reset_index()
spline_avg = sens.groupby(['hour_of_day']).mean()['pm25'].reset_index()

fields = []
times = []
pm25 = []
for i in np.unique(spline['field_egg_id']):
    s_i = spline[spline['field_egg_id']==i]
    x = s_i['hour_of_day'].values
    y = [t for t in s_i['pm25'].values]
    c1 = CubicSpline(x[:8],y[:8])
    c2 = CubicSpline(x[8:16],y[8:16])
    c3 = CubicSpline(x[16:24],y[16:24])
    ix = [k/100.0 for k in range(2400)]
    iy = list(np.concatenate((c1(ix[:800]),c2(ix[800:1600]),c3(ix[1600:2400]))))
    fields += [i]*2400
    times += ix
    pm25 += iy

spline_df = pd.DataFrame((fields, times, pm25)).transpose()

spline_df.columns = ['field_egg_id', 'time', 'pm25']

hours_in_day = np.arange(24).astype(float)

spline_df = spline_df[spline_df['time'].isin(hours_in_day)]

spline_mat = np.transpose(spline_df['pm25'].to_numpy().reshape((60,24))).astype(float)

spline_df = pd.DataFrame(spline_mat,columns=df.columns)
spline_df = spline_df.drop(['Pusa_IMD'], axis=1)
df = df.drop(['Pusa_IMD'], axis=1)
spline_df = spline_df.mean(axis=1)
df_full = deepcopy(df)
for idx,row in df.iterrows():
    df.loc[idx] = row-spline_df.loc[idx.hour]
df_spline = df_full-df

# %%
for col in df.columns:
    X = df[col].dropna().values
    result = adfuller(X)
    # print('ADF Statistic: %f' % result[0])
    print('sensor:{}, p-value: {}'.format(col,result[1]))
    # print('Critical Values:')
    # for key, value in result[4].items():
    #     print('\t%s: %.3f' % (key, value))
# Out:
# sensor:113E, p-value: 0.0001589011860672702
# sensor:1FD7, p-value: 0.0027695135656779016
# sensor:20CA, p-value: 0.0026037429050420552
# sensor:2E9C, p-value: 0.03090348376706523
# sensor:3ACF, p-value: 0.771502861291134
# sensor:498F, p-value: 1.4424604099966026e-07
# sensor:4BE7, p-value: 1.0665251150163475e-05
# sensor:56C3, p-value: 0.0002810986447358
# sensor:5D7A, p-value: 8.716836256524607e-05
# sensor:603A, p-value: 0.0007984998906120299
# sensor:72CA, p-value: 8.690379720135994e-05
# sensor:8E2A, p-value: 0.00023148943496936077
# sensor:91B8, p-value: 0.012784970397089418
# sensor:97D7, p-value: 0.0012037750405288915
# sensor:A838, p-value: 0.0011216013630001341
# sensor:A9BE, p-value: 4.854694027305082e-06
# sensor:AnandVihar_DPCC, p-value: 5.204998673816713e-08
# sensor:AshokVihar_DPCC, p-value: 2.806381383351259e-07
# sensor:AyaNagar_IMD, p-value: 1.2917306651169454e-09
# sensor:BB4A, p-value: 0.19238654709200592
# sensor:BC46, p-value: 0.0002808466744330511
# sensor:BFDC, p-value: 7.26662596570687e-08
# sensor:BurariCrossing_IMD, p-value: 1.1411778056089193e-06
# sensor:C0A7, p-value: 0.0002170365620142646
# sensor:CBC7, p-value: 3.6124857330115424e-05
# sensor:CRRIMathuraRoad_IMD, p-value: 1.2769448271677446e-08
# sensor:D804, p-value: 0.0010496808142263275
# sensor:DF07, p-value: 0.0013164521598821235
# sensor:DKSSR_DPCC, p-value: 7.177005443400022e-08
# sensor:DTU_CPCB, p-value: 1.6165391631809908e-07
# sensor:DwarkaSector8_DPCC, p-value: 6.690823048766471e-08
# sensor:E1F8, p-value: 0.02248861030137327
# sensor:E47A, p-value: 9.70536694084811e-10
# sensor:E486, p-value: 3.251721435963988e-05
# sensor:E8E4, p-value: 0.0007129419039762125
# sensor:EAC8, p-value: 8.68571472369217e-05
# sensor:IGIAirport_IMD, p-value: 6.524882083450806e-08
# sensor:IHBAS_CPCB, p-value: 5.295271735469246e-08
# sensor:ITO_CPCB, p-value: 2.4182606106101427e-08
# sensor:JNS_DPCC, p-value: 3.8725359260464085e-07
# sensor:Jahangirpuri_DPCC, p-value: 8.037950768058279e-07
# sensor:LodhiRoad_IMD, p-value: 2.6937293124753347e-09
# sensor:MDCNS_DPCC, p-value: 1.182318007672808e-07
# sensor:MandirMarg_DPCC, p-value: 1.0010099283389657e-07
# sensor:Mundaka_DPCC, p-value: 8.401483434235195e-07
# sensor:NSIT_CPCB, p-value: 2.1288960989236357e-06
# sensor:NehruNagar_DPCC, p-value: 2.9342375494949548e-06
# sensor:OkhlaPhase2_DPCC, p-value: 3.647967090542326e-07
# sensor:Patparganj_DPCC, p-value: 4.022767300713023e-08
# sensor:PunjabiBagh_DPCC, p-value: 1.9025146526340534e-09
# sensor:Pusa_DPCC, p-value: 2.909583599702149e-06
# sensor:RKPuram_DPCC, p-value: 4.840164264304412e-07
# sensor:Rohini_DPCC, p-value: 6.428318058929877e-07
# sensor:Shadipur_CPCB, p-value: 4.927710416224628e-07
# sensor:Sirifort_CPCB, p-value: 1.315492444936093e-07
# sensor:SoniaVihar_DPCC, p-value: 7.650517748508525e-08
# sensor:SriAurobindoMarg_DPCC, p-value: 1.8972198457207608e-06
# sensor:VivekVihar_DPCC, p-value: 5.214486657902528e-10
# sensor:Wazirpur_DPCC, p-value: 5.581005672311689e-07

# %%
df_daily_avg = df_full.groupby(df_full.index.date).mean()

# %%
for col in df.columns:
    X = df_daily_avg[col].dropna().values
    result = adfuller(X)
    # print('ADF Statistic: %f' % result[0])
    print('sensor:{}, p-value: {}'.format(col,result[1]))
    # print('Critical Values:')
    # for key, value in result[4].items():
    #     print('\t%s: %.3f' % (key, value))
# Out:
# sensor:113E, p-value: 0.5138421266121035
# sensor:1FD7, p-value: 0.02006764872868221
# sensor:20CA, p-value: 0.8531359169131987
# sensor:2E9C, p-value: 0.43884178662890416
# sensor:3ACF, p-value: 0.8903174993233485
# sensor:498F, p-value: 0.41055274298932287
# sensor:4BE7, p-value: 0.37701746625975874
# sensor:56C3, p-value: 0.36174658041265007
# sensor:5D7A, p-value: 0.07435644219395415
# sensor:603A, p-value: 0.20314198264795957
# sensor:72CA, p-value: 0.43989521156715583
# sensor:8E2A, p-value: 0.34081530334536386
# sensor:91B8, p-value: 0.48552414801888844
# sensor:97D7, p-value: 0.7246442247301207
# sensor:A838, p-value: 0.1587262316191556
# sensor:A9BE, p-value: 0.17086062575429312
# sensor:AnandVihar_DPCC, p-value: 0.025238609966519585
# sensor:AshokVihar_DPCC, p-value: 0.0245868068467886
# sensor:AyaNagar_IMD, p-value: 0.03401431569805104
# sensor:BB4A, p-value: 0.877280708644475
# sensor:BC46, p-value: 0.22729233075990407
# sensor:BFDC, p-value: 0.13465214566080214
# sensor:BurariCrossing_IMD, p-value: 0.02567364094487911
# sensor:C0A7, p-value: 0.7403546792670971
# sensor:CBC7, p-value: 0.5370714957612973
# sensor:CRRIMathuraRoad_IMD, p-value: 0.0225249970413162
# sensor:D804, p-value: 0.40354946314738593
# sensor:DF07, p-value: 0.7429471129558226
# sensor:DKSSR_DPCC, p-value: 0.18954401711369578
# sensor:DTU_CPCB, p-value: 0.10088592641537941
# sensor:DwarkaSector8_DPCC, p-value: 0.02862841820690891
# sensor:E1F8, p-value: 0.843621187913516
# sensor:E47A, p-value: 0.007055233222760355
# sensor:E486, p-value: 0.29962632255936184
# sensor:E8E4, p-value: 0.4969167039080118
# sensor:EAC8, p-value: 0.40991163292402144
# sensor:IGIAirport_IMD, p-value: 0.08468761410620695
# sensor:IHBAS_CPCB, p-value: 0.048519662246509186
# sensor:ITO_CPCB, p-value: 0.01699315856993054
# sensor:JNS_DPCC, p-value: 0.05729725225037328
# sensor:Jahangirpuri_DPCC, p-value: 0.05060939386759372
# sensor:LodhiRoad_IMD, p-value: 0.10487487188764738
# sensor:MDCNS_DPCC, p-value: 0.01926676484079708
# sensor:MandirMarg_DPCC, p-value: 0.05180879986833542
# sensor:Mundaka_DPCC, p-value: 0.05485100526562311
# sensor:NSIT_CPCB, p-value: 0.06923603617274547
# sensor:NehruNagar_DPCC, p-value: 0.05203295012593535
# sensor:OkhlaPhase2_DPCC, p-value: 0.05940358156060158
# sensor:Patparganj_DPCC, p-value: 0.01895253208796124
# sensor:PunjabiBagh_DPCC, p-value: 0.015530135066836112
# sensor:Pusa_DPCC, p-value: 0.09577412933572388
# sensor:RKPuram_DPCC, p-value: 0.10026349135656892
# sensor:Rohini_DPCC, p-value: 0.04030920269039424
# sensor:Shadipur_CPCB, p-value: 0.06554030099910446
# sensor:Sirifort_CPCB, p-value: 0.039255956423549204
# sensor:SoniaVihar_DPCC, p-value: 0.07803561543546228
# sensor:SriAurobindoMarg_DPCC, p-value: 0.05151059962523987
# sensor:VivekVihar_DPCC, p-value: 0.027624560369866793
# sensor:Wazirpur_DPCC, p-value: 0.050419769568667915
