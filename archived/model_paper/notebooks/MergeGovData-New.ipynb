# %%
# notebook to load the raw govt (CPCB/DPCC/IMD) data in the Excel sheet format and save them as csvs with latitude 
# and longitude fields

# %matplotlib inline

#from openpyxl import Workbook
#from openpyxl import load_workbook
#import json
#from datetime import datetime
#from datetime import timedelta

import os, sys
import importlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob

sys.path.insert(0, '..')

# %%
import preprocess
importlib.reload(preprocess)
from preprocess import read_xlsx

# %%
# load all the Excel sheets from the source folder on Dropbox

#suffix = '1H_May2018_Feb2020'
#suffix = '1H_Feb2020_May2020'
#sheets = sorted(glob('data/govdata/*.xlsx'), key=lambda name: int(name.split('/data')[1].replace('.xlsx','')))
#sheets = sorted(glob('/home/shivar/Dropbox/Delhi Pollution/07_Data_Secondary/CPCB/Raw/*.xlsx'))
#fileslist = glob('/home/shivar/Dropbox/Delhi Pollution/07_Data_Secondary/CPCB/Raw/*_{}.xlsx'.format(suffix))
#fileslist = glob('../data/govdata/raw/CPCB_Raw_{0}/*_{0}.xlsx'.format(suffix))

start_dt_str = '2018-05-01'
end_dt_str = '2020-11-01'
fileslist = glob('../data/govdata/raw/CPCB_Raw_*/*.xlsx')
fileslist.sort()
for fpath in fileslist:
    print(os.path.basename(fpath))
# Out:
# AshokVihar_DPCC_AnandVihar_DPCC_1H_Feb2020_May2020.xlsx
# BurariCrossing_IMD_AyaNagar_IMD_1H_Feb2020_May2020.xlsx
# DTU_CPCB_CRRIMathuraRoad_IMD_1H_Feb2020_May2020.xlsx
# DwarkaSector8_DPCC_DKSSR_DPCC_1H_Feb2020_May2020.xlsx
# IHBAS_CPCB_IGIAirport_IMD_1H_Feb2020_May2020.xlsx
# Jahangirpuri_DPCC_ITO_CPCB_1H_Feb2020_May2020.xlsx
# LodhiRoad_IMD_JNS_DPCC_1H_Feb2020_May2020.xlsx
# MandirMarg_DPCC_MDCNS_DPCC_1H_Feb2020_May2020.xlsx
# NSIT_CPCB_Mundaka_DPCC_1H_Feb2020_May2020.xlsx
# OkhlaPhase2_DPCC_NehruNagar_DPCC_1H_Feb2020_May2020.xlsx
# PunjabiBagh_DPCC_Patparganj_DPCC_1H_Feb2020_May2020.xlsx
# Pusa_IMD_Pusa_DPCC_1H_Feb2020_May2020.xlsx
# Rohini_DPCC_RKPuram_DPCC_1H_Feb2020_May2020.xlsx
# Sirifort_CPCB_Shadipur_CPCB_1H_Feb2020_May2020.xlsx
# SriAurobindoMarg_DPCC_SoniaVihar_DPCC_1H_Feb2020_May2020.xlsx
# VivekVihar_DPCC_Wazirpur_DPCC_1H_Feb2020_May2020.xlsx
# AnandVihar_DPCC_1H_May2018_Feb2020.xlsx
# AshokVihar_DPCC_1H_May2018_Feb2020.xlsx
# AyaNagar_IMD_1H_May2018_Feb2020.xlsx
# BurariCrossing_IMD_1H_May2018_Feb2020.xlsx
# CRRIMathuraRoad_IMD_1H_May2018_Feb2020.xlsx
# DKSSR_DPCC_1H_May2018_Feb2020.xlsx
# DTU_CPCB_1H_May2018_Feb2020.xlsx
# DwarkaSector8_DPCC_1H_May2018_Feb2020.xlsx
# IGIAirport_IMD_1H_May2018_Feb2020.xlsx
# IHBAS_CPCB_ITO_CPCB_1H_May2018_Feb2020.xlsx
# Jahangirpuri_DPCC_JNS_DPCC_1H_May2018_Feb2020.xlsx
# LodhiRoad_IMD_MandirMarg_DPCC_1H_May2018_Feb2020.xlsx
# MDCNS_DPCC_Mundaka_DPCC_1H_May2018_Feb2020.xlsx
# NSIT_CPCB_OkhlaPhase2_DPCC_1H_May2018_Feb2020.xlsx
# NehruNagar_DPCC_NorthCampusDU_IMD_1H_May2018_Feb2020.xlsx
# Patparganj_DPCC_PunjabiBagh_DPCC_1H_May2018_Feb2020.xlsx
# Pusa_DPCC_Pusa_IMD_1H_May2018_Feb2020.xlsx
# RKPuram_DPCC_Rohini_DPCC_1H_May2018_Feb2020.xlsx
# Shadipur_CPCB_Sirifort_CPCB_1H_May2018_Feb2020.xlsx
# SoniaVihar_DPCC_SriAurobindoMarg_DPCC_1H_May2018_Feb2020.xlsx
# VivekVihar_DPCC_Wazirpur_DPCC_1H_May2018_Feb2020.xlsx
# AnandVihar_DPCC_AshokVihar_DPCC_1H_May2020_Nov2020.xlsx
# AyaNagar_IMD_BurariCrossing_IMD_1H_May2020_Nov2020.xlsx
# CRRIMathuraRoad_IMD_DTU_CPCB_1H_May2020_Nov2020.xlsx
# DKSSR_DPCC_DwarkaSector8_DPCC_1H_May2020_Nov2020.xlsx
# IGIAirport_IMD_IHBAS_CPCB_1H_May2020_Nov2020.xlsx
# ITO_CPCB_Jahangirpuri_DPCC_1H_May2020_Nov2020.xlsx
# JNS_DPCC_LodhiRoad_IMD_1H_May2020_Nov2020.xlsx
# MandirMarg_DPCC_MDCNS_DPCC_1H_May2020_Nov2020.xlsx
# Mundaka_DPCC_NSIT_CPCB_1H_May2020_Nov2020.xlsx
# NehruNagar_DPCC_OkhlaPhase2_DPCC_1H_May2020_Nov2020.xlsx
# Patparganj_DPCC_PunjabiBagh_DPCC_1H_May2020_Nov2020.xlsx
# Pusa_DPCC_Pusa_IMD_1H_May2020_Nov2020.xlsx
# RKPuram_DPCC_Rohini_DPCC_1H_May2020_Nov2020.xlsx
# Shadipur_CPCB_Sirifort_CPCB_1H_May2020_Nov2020.xlsx
# SoniaVihar_DPCC_SriAurobindoMarg_DPCC_1H_May2020_Nov2020.xlsx
# VivekVihar_DPCC_Wazirpur_DPCC_1H_May2020_Nov2020.xlsx

# %%
data_list = read_xlsx(fileslist[0])
# Out:
# Number of monitors: 2
# Reading data for AshokVihar_DPCC
# Reading data for AnandVihar_DPCC

# %%
print(len(data_list))

for name, data in data_list:
    print(name, data.shape)
    print(data.iloc[0,:])
    print(data.iloc[-1,:])
# Out:
# 2
# AshokVihar_DPCC (2160, 6)
# AT        8.57
# RH       86.22
# WD       38.92
# WS        0.35
# pm10    196.50
# pm25    122.00
# Name: 2020-02-01 00:00:00+05:30, dtype: float64
# AT       27.28
# RH       54.77
# WD       31.73
# WS        1.17
# pm10    120.00
# pm25     80.50
# Name: 2020-04-30 23:00:00+05:30, dtype: float64
# AnandVihar_DPCC (2160, 6)
# AT       14.68
# RH       85.40
# WD      229.75
# WS        0.30
# pm10    254.75
# pm25    101.50
# Name: 2020-02-01 00:00:00+05:30, dtype: float64
# AT     NaN
# RH     NaN
# WD     NaN
# WS     NaN
# pm10   NaN
# pm25   NaN
# Name: 2020-04-30 23:00:00+05:30, dtype: float64

# %%
# sample plot of the data as an example illustration
name, df = data_list[0]

plt.figure(figsize=(14, 5))
plt.title('PM2.5 and PM10')
df.pm25.plot(ax=plt.gca())
df.pm10.plot(ax=plt.gca())
plt.legend()

plt.figure(figsize=(14, 5))
plt.title('Temp and Humidity')
df.AT.plot(ax=plt.gca(), c='b')
plt.ylabel('Temp')
plt.legend(loc=2)
plt.twinx()
df.RH.plot(ax=plt.gca(), c='r')
plt.ylabel('Humidity')
plt.legend(loc=1)

plt.figure(figsize=(14, 5))
plt.title('Wind Direction and Speed')
df.WD.plot(ax=plt.gca(), c='b')
plt.ylabel('Wind Direction')
plt.legend(loc=2)
plt.twinx()
df.WS.plot(ax=plt.gca(), c='r')
plt.ylabel('Wind Speed')
plt.legend(loc=1)

plt.show()
plt.close('all')

# %%
# import json

# # reading in the metadata to get the latitudes and longitudes
# locsdict = dict()

# with open('data/gov_metadata.json')as fl:
#     stations = json.load(fl)

# for station in stations['map']['station_list']:
#     nm = station['station_name']
#     locsdict[nm] = (float(station['latitude']), float(station['longitude']))

# %%
# print(len(locsdict))
# locsdict

# %%
# # correct errors (see notes.txt in the same folder as this notebook)
# # (1) remove DU north campus
# # (2) swap RK Puram and Punjabi Bagh locations
# locsdict.__delitem__('North Campus, DU, New Delhi - IMD')
# locsdict['Punjabi Bagh, Delhi - DPCC'] = (28.674045, 77.131023)
# locsdict['R K Puram, New Delhi - DPCC'] = (28.563262, 77.186937)

# %%
# saving individual dataframes as individual csvs, and also saving a combined BIG csv
dfs_list = []

for fii, fpath in enumerate(fileslist):
    print('{}/{} {}'.format(fii + 1, len(fileslist), os.path.basename(fpath)))
    
    data_list = read_xlsx(fpath)
    
    for name, df in data_list:
        df['monitor_id'] = name
        df.reset_index(inplace=True)
        df.set_index(['monitor_id', 'timestamp_round'], inplace=True)
        dfs_list.append(df)
    
#     for monitorid, df in data_list:
#         df = df.loc[slice(start_dt, end_dt),:]
#         df = df.iloc[:-1] # for some reason the first row for Feb 1, 2020 is getting included, hence removing that
#         df.to_csv(os.path.join(subsavedir, monitorid + '.csv'))
        
#         df['monitor_id'] = monitorid
#         df.reset_index(inplace=True)
#         df.set_index(['monitor_id', 'timestamp_round'], inplace=True)
#         dfs_list.append(df)
# Out:
# 1/53 AshokVihar_DPCC_AnandVihar_DPCC_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for AshokVihar_DPCC
# Reading data for AnandVihar_DPCC
# 2/53 BurariCrossing_IMD_AyaNagar_IMD_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for BurariCrossing_IMD
# Reading data for AyaNagar_IMD
# 3/53 DTU_CPCB_CRRIMathuraRoad_IMD_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for DTU_CPCB
# Reading data for CRRIMathuraRoad_IMD
# 4/53 DwarkaSector8_DPCC_DKSSR_DPCC_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for DwarkaSector8_DPCC
# Reading data for DKSSR_DPCC
# 5/53 IHBAS_CPCB_IGIAirport_IMD_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for IHBAS_CPCB
# Reading data for IGIAirport_IMD
# 6/53 Jahangirpuri_DPCC_ITO_CPCB_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for Jahangirpuri_DPCC
# Reading data for ITO_CPCB
# 7/53 LodhiRoad_IMD_JNS_DPCC_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for LodhiRoad_IMD
# Reading data for JNS_DPCC
# 8/53 MandirMarg_DPCC_MDCNS_DPCC_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for MandirMarg_DPCC
# Reading data for MDCNS_DPCC
# 9/53 NSIT_CPCB_Mundaka_DPCC_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for NSIT_CPCB
# Reading data for Mundaka_DPCC
# 10/53 OkhlaPhase2_DPCC_NehruNagar_DPCC_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for OkhlaPhase2_DPCC
# Reading data for NehruNagar_DPCC
# 11/53 PunjabiBagh_DPCC_Patparganj_DPCC_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for PunjabiBagh_DPCC
# Reading data for Patparganj_DPCC
# 12/53 Pusa_IMD_Pusa_DPCC_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for Pusa_IMD
# Reading data for Pusa_DPCC
# 13/53 Rohini_DPCC_RKPuram_DPCC_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for Rohini_DPCC
# Reading data for RKPuram_DPCC
# 14/53 Sirifort_CPCB_Shadipur_CPCB_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for Sirifort_CPCB
# Reading data for Shadipur_CPCB
# 15/53 SriAurobindoMarg_DPCC_SoniaVihar_DPCC_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for SriAurobindoMarg_DPCC
# Reading data for SoniaVihar_DPCC
# 16/53 VivekVihar_DPCC_Wazirpur_DPCC_1H_Feb2020_May2020.xlsx
# Number of monitors: 2
# Reading data for VivekVihar_DPCC
# Reading data for Wazirpur_DPCC
# 17/53 AnandVihar_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 1
# Reading data for AnandVihar_DPCC
# 18/53 AshokVihar_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 1
# Reading data for AshokVihar_DPCC
# 19/53 AyaNagar_IMD_1H_May2018_Feb2020.xlsx
# Number of monitors: 1
# Reading data for AyaNagar_IMD
# 20/53 BurariCrossing_IMD_1H_May2018_Feb2020.xlsx
# Number of monitors: 1
# Reading data for BurariCrossing_IMD
# 21/53 CRRIMathuraRoad_IMD_1H_May2018_Feb2020.xlsx
# Number of monitors: 1
# Reading data for CRRIMathuraRoad_IMD
# 22/53 DKSSR_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 1
# Reading data for DKSSR_DPCC
# 23/53 DTU_CPCB_1H_May2018_Feb2020.xlsx
# Number of monitors: 1
# Reading data for DTU_CPCB
# 24/53 DwarkaSector8_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 1
# Reading data for DwarkaSector8_DPCC
# 25/53 IGIAirport_IMD_1H_May2018_Feb2020.xlsx
# Number of monitors: 1
# Reading data for IGIAirport_IMD
# 26/53 IHBAS_CPCB_ITO_CPCB_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for IHBAS_CPCB
# Reading data for ITO_CPCB
# 27/53 Jahangirpuri_DPCC_JNS_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for Jahangirpuri_DPCC
# Reading data for JNS_DPCC
# 28/53 LodhiRoad_IMD_MandirMarg_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for LodhiRoad_IMD
# Reading data for MandirMarg_DPCC
# 29/53 MDCNS_DPCC_Mundaka_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for MDCNS_DPCC
# Reading data for Mundaka_DPCC
# 30/53 NSIT_CPCB_OkhlaPhase2_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for NSIT_CPCB
# Reading data for OkhlaPhase2_DPCC
# 31/53 NehruNagar_DPCC_NorthCampusDU_IMD_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for NehruNagar_DPCC
# Reading data for NorthCampusDU_IMD
# 32/53 Patparganj_DPCC_PunjabiBagh_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for Patparganj_DPCC
# Reading data for PunjabiBagh_DPCC
# 33/53 Pusa_DPCC_Pusa_IMD_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for Pusa_DPCC
# Reading data for Pusa_IMD
# 34/53 RKPuram_DPCC_Rohini_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for RKPuram_DPCC
# Reading data for Rohini_DPCC
# 35/53 Shadipur_CPCB_Sirifort_CPCB_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for Shadipur_CPCB
# Reading data for Sirifort_CPCB
# 36/53 SoniaVihar_DPCC_SriAurobindoMarg_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for SoniaVihar_DPCC
# Reading data for SriAurobindoMarg_DPCC
# 37/53 VivekVihar_DPCC_Wazirpur_DPCC_1H_May2018_Feb2020.xlsx
# Number of monitors: 2
# Reading data for VivekVihar_DPCC
# Reading data for Wazirpur_DPCC
# 38/53 AnandVihar_DPCC_AshokVihar_DPCC_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for AnandVihar_DPCC
# Reading data for AshokVihar_DPCC
# 39/53 AyaNagar_IMD_BurariCrossing_IMD_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for AyaNagar_IMD
# Reading data for BurariCrossing_IMD
# 40/53 CRRIMathuraRoad_IMD_DTU_CPCB_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for CRRIMathuraRoad_IMD
# Reading data for DTU_CPCB
# 41/53 DKSSR_DPCC_DwarkaSector8_DPCC_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for DKSSR_DPCC
# Reading data for DwarkaSector8_DPCC
# 42/53 IGIAirport_IMD_IHBAS_CPCB_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for IGIAirport_IMD
# Reading data for IHBAS_CPCB
# 43/53 ITO_CPCB_Jahangirpuri_DPCC_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for ITO_CPCB
# Reading data for Jahangirpuri_DPCC
# 44/53 JNS_DPCC_LodhiRoad_IMD_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for JNS_DPCC
# Reading data for LodhiRoad_IMD
# 45/53 MandirMarg_DPCC_MDCNS_DPCC_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for MandirMarg_DPCC
# Reading data for MDCNS_DPCC
# 46/53 Mundaka_DPCC_NSIT_CPCB_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for Mundaka_DPCC
# Reading data for NSIT_CPCB
# 47/53 NehruNagar_DPCC_OkhlaPhase2_DPCC_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for NehruNagar_DPCC
# Reading data for OkhlaPhase2_DPCC
# 48/53 Patparganj_DPCC_PunjabiBagh_DPCC_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for Patparganj_DPCC
# Reading data for PunjabiBagh_DPCC
# 49/53 Pusa_DPCC_Pusa_IMD_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for Pusa_DPCC
# Reading data for Pusa_IMD
# 50/53 RKPuram_DPCC_Rohini_DPCC_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for RKPuram_DPCC
# Reading data for Rohini_DPCC
# 51/53 Shadipur_CPCB_Sirifort_CPCB_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for Shadipur_CPCB
# Reading data for Sirifort_CPCB
# 52/53 SoniaVihar_DPCC_SriAurobindoMarg_DPCC_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for SoniaVihar_DPCC
# Reading data for SriAurobindoMarg_DPCC
# 53/53 VivekVihar_DPCC_Wazirpur_DPCC_1H_May2020_Nov2020.xlsx
# Number of monitors: 2
# Reading data for VivekVihar_DPCC
# Reading data for Wazirpur_DPCC

# %%
df = pd.concat(dfs_list, axis=0)

# sort index and remove duplicates
df.sort_index(inplace=True)
df = df.loc[~df.index.duplicated(),:]

# select data only between specified start and end dates
start_dt = pd.Timestamp(start_dt_str, tz='Asia/Kolkata')
end_dt = pd.Timestamp(end_dt_str, tz='Asia/Kolkata') 
end_slice_dt = end_dt - pd.Timedelta(hours=1) # not including this last timestamp in the data while slicing
df = df.loc[(slice(None), slice(start_dt, end_slice_dt)), :]

# remove NorthCampusDU_IMD
df.drop('NorthCampusDU_IMD', level=0, inplace=True)

print('Number of locations:', df.index.get_level_values(0).unique().size)
print('Total number of entries:', df.shape[0])
print('Number of entries per location:', df.shape[0] / df.index.get_level_values(0).unique().size)

df
# Out:
# Number of locations: 32
# Total number of entries: 702720
# Number of entries per location: 21960.0
#                                               AT     RH      WD    WS   pm10  \
# monitor_id      timestamp_round
# AnandVihar_DPCC 2018-05-01 00:00:00+05:30  30.32  49.85   98.17  3.67  295.0
#                 2018-05-01 01:00:00+05:30  29.44  51.58   88.67  4.11  202.0
#                 2018-05-01 02:00:00+05:30  28.19  56.00   89.58  4.31  163.0
#                 2018-05-01 03:00:00+05:30  26.89  62.42   89.75  5.03  140.0
#                 2018-05-01 04:00:00+05:30  26.27  64.75   84.50  6.12  151.0
# ...                                          ...    ...     ...   ...    ...
# Wazirpur_DPCC   2020-10-31 19:00:00+05:30  23.85  29.40  314.95  1.30  377.0
#                 2020-10-31 20:00:00+05:30  22.90  29.40  313.67  1.18  430.5
#                 2020-10-31 21:00:00+05:30  22.10  29.40  318.20  1.23  468.5
#                 2020-10-31 22:00:00+05:30  21.95  29.40  329.62  1.20  509.0
#                 2020-10-31 23:00:00+05:30  21.10  29.40  314.73  1.35  580.5
#
#                                             pm25
# monitor_id      timestamp_round
# AnandVihar_DPCC 2018-05-01 00:00:00+05:30   68.0
#                 2018-05-01 01:00:00+05:30   53.0
#                 2018-05-01 02:00:00+05:30   53.0
#                 2018-05-01 03:00:00+05:30   46.0
#                 2018-05-01 04:00:00+05:30   48.0
# ...                                          ...
# Wazirpur_DPCC   2020-10-31 19:00:00+05:30   87.0
#                 2020-10-31 20:00:00+05:30  111.0
#                 2020-10-31 21:00:00+05:30  149.0
#                 2020-10-31 22:00:00+05:30  196.0
#                 2020-10-31 23:00:00+05:30  246.0
#
# [702720 rows x 6 columns]

# %%
# save it 
newsuffix = '1H_{}_{}'.format(start_dt.strftime('%Y%m%d'), end_dt.strftime('%Y%m%d'))

savedir = '../data/govdata/'
subsavedir = os.path.join(savedir, 'govdata_' + newsuffix)
if not os.path.exists(subsavedir):
    os.makedirs(subsavedir)

df.to_csv(os.path.join(savedir, 'govdata_{}.csv'.format(newsuffix)))

grouped = df.groupby(level=0)
for name, group in grouped:
    group.droplevel(0).to_csv(os.path.join(subsavedir, name + '.csv'))

# %%
savedir
# Out:
# '/home/shivar/Dropbox/Delhi Pollution/07_Data_Secondary/CPCB_Oct2018/Raw'

# %%
locs_list
# Out:
# [('AnandVihar_DPCC', 28.646835, 77.316032, 'Anand Vihar, Delhi - DPCC'),
#  ('AshokVihar_DPCC', 28.695381, 77.181665, 'Ashok Vihar, Delhi - DPCC'),
#  ('AyaNagar_IMD', 28.4706914, 77.1099364, 'Aya Nagar, New Delhi - IMD'),
#  ('BurariCrossing_IMD',
#   28.7256504,
#   77.2011573,
#   'Burari Crossing, New Delhi - IMD'),
#  ('CRRIMathuraRoad_IMD',
#   28.5512005,
#   77.2735737,
#   'CRRI Mathura Road, New Delhi - IMD'),
#  ('DKSSR_DPCC',
#   28.498571,
#   77.26484,
#   'Dr. Karni Singh Shooting Range, Delhi - DPCC'),
#  ('DTU_CPCB', 28.7500499, 77.1112615, 'DTU, New Delhi - CPCB'),
#  ('DwarkaSector8_DPCC',
#   28.5710274,
#   77.0719006,
#   'Dwarka-Sector 8, Delhi - DPCC '),
#  ('EastArjunNagar_CPCB',
#   28.6556017,
#   77.2859318,
#   'East Arjun Nagar, Delhi - CPCB'),
#  ('IGIAirport_IMD',
#   28.5627763,
#   77.1180053,
#   'IGI Airport (T3), New Delhi - IMD'),
#  ('IHBAS_CPCB',
#   28.6811736,
#   77.3025234,
#   'IHBAS, Dilshad Garden,New Delhi - CPCB'),
#  ('ITO_CPCB', 28.6316945, 77.2494387, 'ITO, New Delhi - CPCB'),
#  ('JNS_DPCC', 28.58028, 77.233829, 'Jawaharlal Nehru Stadium, Delhi - DPCC'),
#  ('Jahangirpuri_DPCC', 28.73282, 77.170633, 'Jahangirpuri, Delhi - DPCC'),
#  ('LodhiRoad_IMD', 28.5918245, 77.2273074, 'Lodhi Road, New Delhi - IMD'),
#  ('MDCNS_DPCC',
#   28.611281,
#   77.237738,
#   'Major Dhyan Chand National Stadium, Delhi - DPCC'),
#  ('MandirMarg_DPCC', 28.636429, 77.201067, 'Mandir Marg, New Delhi - DPCC'),
#  ('Mundaka_DPCC', 28.684678, 77.076574, 'Mundaka, Delhi - DPCC'),
#  ('NSIT_CPCB', 28.60909, 77.0325413, 'NSIT Dwarka, New Delhi - CPCB'),
#  ('NehruNagar_DPCC', 28.56789, 77.250515, 'Nehru Nagar, Delhi - DPCC'),
#  ('OkhlaPhase2_DPCC', 28.530785, 77.271255, 'Okhla Phase-2, Delhi - DPCC'),
#  ('Patparganj_DPCC', 28.623748, 77.287205, 'Patparganj, Delhi - DPCC'),
#  ('PunjabiBagh_DPCC', 28.674045, 77.131023, 'Punjabi Bagh, Delhi - DPCC'),
#  ('Pusa_DPCC', 28.639645, 77.146262, 'Pusa, Delhi - DPCC'),
#  ('Pusa_IMD', 28.639645, 77.146263, 'Pusa, New Delhi - IMD'),
#  ('RKPuram_DPCC', 28.563262, 77.186937, 'R K Puram, New Delhi - DPCC'),
#  ('Rohini_DPCC', 28.732528, 77.11992, 'Rohini, Delhi - DPCC'),
#  ('Shadipur_CPCB', 28.6514781, 77.1473105, 'Shadipur, New Delhi - CPCB'),
#  ('Sirifort_CPCB', 28.5504249, 77.2159377, 'Sirifort, New Delhi - CPCB'),
#  ('SoniaVihar_DPCC', 28.710508, 77.249485, 'Sonia Vihar, Delhi - DPCC'),
#  ('SriAurobindoMarg_DPCC',
#   28.531346,
#   77.190156,
#   'Sri Aurobindo Marg, Delhi - DPCC'),
#  ('VivekVihar_DPCC', 28.672342, 77.31526, 'Vivek Vihar, Delhi - DPCC'),
#  ('Wazirpur_DPCC', 28.699793, 77.165453, 'Wazirpur, Delhi - DPCC')]

# %%
# colnames = ['Monitor ID', 'Latitude', 'Longitude', 'Location']
# collen_0 = max([len(colnames[0])] + [len(tup[0]) for tup in locs_list]) + 1
# collen_1 = max([len(colnames[1])] + [len(str(tup[1])) for tup in locs_list]) + 1
# collen_2 = max([len(colnames[2])] + [len(str(tup[2])) for tup in locs_list]) + 1

# fout = open(os.path.join(savedir, 'govdata_locations.csv'), 'w')
# fout.write('{{:{}}},{{:>{}}},{{:>{}}}, {{}}\n'.format(collen_0, collen_1, collen_2).format(*colnames))

# for locid, lat, lon, locname in locs_list:
#     fout.write('{{:{}}},{{:>{}}},{{:>{}}}, {{}}\n'.format(collen_0, collen_1, collen_2).format(locid, str(lat), str(lon), '"' + locname + '"'))
# fout.close()

# %%
# create dataframe and export to csv (above does not work)
locs_df = pd.DataFrame.from_records(locs_list, columns=['Monitor ID', 'Latitude', 'Longitude', 'Location'])
locs_df.set_index('Monitor ID', inplace=True)
locs_df
# Out:
#                         Latitude  Longitude  \
# Monitor ID
# AnandVihar_DPCC        28.646835  77.316032
# AshokVihar_DPCC        28.695381  77.181665
# AyaNagar_IMD           28.470691  77.109936
# BurariCrossing_IMD     28.725650  77.201157
# CRRIMathuraRoad_IMD    28.551201  77.273574
# DKSSR_DPCC             28.498571  77.264840
# DTU_CPCB               28.750050  77.111261
# DwarkaSector8_DPCC     28.571027  77.071901
# EastArjunNagar_CPCB    28.655602  77.285932
# IGIAirport_IMD         28.562776  77.118005
# IHBAS_CPCB             28.681174  77.302523
# ITO_CPCB               28.631694  77.249439
# JNS_DPCC               28.580280  77.233829
# Jahangirpuri_DPCC      28.732820  77.170633
# LodhiRoad_IMD          28.591825  77.227307
# MDCNS_DPCC             28.611281  77.237738
# MandirMarg_DPCC        28.636429  77.201067
# Mundaka_DPCC           28.684678  77.076574
# NSIT_CPCB              28.609090  77.032541
# NehruNagar_DPCC        28.567890  77.250515
# OkhlaPhase2_DPCC       28.530785  77.271255
# Patparganj_DPCC        28.623748  77.287205
# PunjabiBagh_DPCC       28.674045  77.131023
# Pusa_DPCC              28.639645  77.146262
# Pusa_IMD               28.639645  77.146263
# RKPuram_DPCC           28.563262  77.186937
# Rohini_DPCC            28.732528  77.119920
# Shadipur_CPCB          28.651478  77.147311
# Sirifort_CPCB          28.550425  77.215938
# SoniaVihar_DPCC        28.710508  77.249485
# SriAurobindoMarg_DPCC  28.531346  77.190156
# VivekVihar_DPCC        28.672342  77.315260
# Wazirpur_DPCC          28.699793  77.165453
#
#                                                                Location
# Monitor ID
# AnandVihar_DPCC                               Anand Vihar, Delhi - DPCC
# AshokVihar_DPCC                               Ashok Vihar, Delhi - DPCC
# AyaNagar_IMD                                 Aya Nagar, New Delhi - IMD
# BurariCrossing_IMD                     Burari Crossing, New Delhi - IMD
# CRRIMathuraRoad_IMD                  CRRI Mathura Road, New Delhi - IMD
# DKSSR_DPCC                 Dr. Karni Singh Shooting Range, Delhi - DPCC
# DTU_CPCB                                          DTU, New Delhi - CPCB
# DwarkaSector8_DPCC                       Dwarka-Sector 8, Delhi - DPCC
# EastArjunNagar_CPCB                      East Arjun Nagar, Delhi - CPCB
# IGIAirport_IMD                        IGI Airport (T3), New Delhi - IMD
# IHBAS_CPCB                       IHBAS, Dilshad Garden,New Delhi - CPCB
# ITO_CPCB                                          ITO, New Delhi - CPCB
# JNS_DPCC                         Jawaharlal Nehru Stadium, Delhi - DPCC
# Jahangirpuri_DPCC                            Jahangirpuri, Delhi - DPCC
# LodhiRoad_IMD                               Lodhi Road, New Delhi - IMD
# MDCNS_DPCC             Major Dhyan Chand National Stadium, Delhi - DPCC
# MandirMarg_DPCC                           Mandir Marg, New Delhi - DPCC
# Mundaka_DPCC                                      Mundaka, Delhi - DPCC
# NSIT_CPCB                                 NSIT Dwarka, New Delhi - CPCB
# NehruNagar_DPCC                               Nehru Nagar, Delhi - DPCC
# OkhlaPhase2_DPCC                            Okhla Phase-2, Delhi - DPCC
# Patparganj_DPCC                                Patparganj, Delhi - DPCC
# PunjabiBagh_DPCC                             Punjabi Bagh, Delhi - DPCC
# Pusa_DPCC                                            Pusa, Delhi - DPCC
# Pusa_IMD                                          Pusa, New Delhi - IMD
# RKPuram_DPCC                                R K Puram, New Delhi - DPCC
# Rohini_DPCC                                        Rohini, Delhi - DPCC
# Shadipur_CPCB                                Shadipur, New Delhi - CPCB
# Sirifort_CPCB                                Sirifort, New Delhi - CPCB
# SoniaVihar_DPCC                               Sonia Vihar, Delhi - DPCC
# SriAurobindoMarg_DPCC                  Sri Aurobindo Marg, Delhi - DPCC
# VivekVihar_DPCC                               Vivek Vihar, Delhi - DPCC
# Wazirpur_DPCC                                    Wazirpur, Delhi - DPCC

# %%
locs_df.to_csv(os.path.join(savedir, 'govdata_locations.csv'))
