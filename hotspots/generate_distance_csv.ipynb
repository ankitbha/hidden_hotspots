# %%
# %load_ext autoreload
# %autoreload 2
import os, sys
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append('../')

# %%
from datasets import *

# %%
datadir = '/scratch/ab9738/epod-nyu-delhi-pollution/data/'

# %%
get_adjacency_matrix(datadir)
# Out:
#                           113E     1FD7     20CA     2E9C     3ACF     498F  \
# Monitor ID
# 113E                       0.0   5806.0   8916.0   5684.0   4271.0   1671.0
# 1FD7                    5806.0      0.0   3111.0   4631.0   3333.0   4386.0
# 20CA                    8916.0   3111.0      0.0   6504.0   5866.0   7481.0
# 2E9C                    5684.0   4631.0   6504.0      0.0   1798.0   5483.0
# 3ACF                    4271.0   3333.0   5866.0   1798.0      0.0   3777.0
# ...                        ...      ...      ...      ...      ...      ...
# Sirifort_CPCB           2988.0   2930.0   5999.0   3731.0   1940.0   1967.0
# SoniaVihar_DPCC        18326.0  17109.0  17369.0  21463.0  19758.0  17115.0
# SriAurobindoMarg_DPCC   5666.0   3733.0   5573.0    947.0   1425.0   5188.0
# VivekVihar_DPCC        15641.0  17006.0  18568.0  20372.0  18577.0  15047.0
# Wazirpur_DPCC          18854.0  15144.0  13884.0  19752.0  18421.0  17254.0
#
# ...
