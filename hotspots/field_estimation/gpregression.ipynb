# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import pytz
import argparse
# import jax.numpy as jnp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from geopy import distance
import datetime
import tilemapbase
from copy import deepcopy
import pickle as pkl
from PIL import Image
import skimage.measure
import math
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
os.environ['PYTHONWARNINGS']='ignore'
import hyperopt
from joblib import Parallel, delayed
import random
random.seed(42)
import scipy
import torch
from pykrige.ok import OrdinaryKriging
from pykrige.ok3d import OrdinaryKriging3D
from pykrige.uk import UniversalKriging
from sklearn.model_selection import train_test_split
from scipy.interpolate import CubicSpline
from sklearn.gaussian_process import GaussianProcessRegressor
import sklearn.gaussian_process.kernels as kernels
import gpflow
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2023-08-22 16:17:05.444202: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-22 16:17:06.321002: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-22 16:17:07.726361: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-22 16:17:07.727706: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-22 16:17:23.416086: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
source = 'combined'
sensor = 'pm25'
res_time = '1H'
filepath_root = '/scratch/ab9738/pollution_with_sensors/'

# %% [markdown]
# # Data Loading

# %%
filepath_data_kai = filepath_root+'data/kaiterra/kaiterra_fieldeggid_{}_current_panel.csv'.format(res_time)
filepath_data_gov = filepath_root+'data/govdata/govdata_{}_current.csv'.format(res_time)
filepath_locs_kai = filepath_root+'data/kaiterra/kaiterra_locations.csv'
filepath_locs_gov = filepath_root+'data/govdata/govdata_locations.csv'

locs_kai = pd.read_csv(filepath_locs_kai, index_col=[0])
locs_kai['Type'] = 'Kaiterra'
locs_gov = pd.read_csv(filepath_locs_gov, index_col=[0])
locs_gov['Type'] = 'Govt'
locs = pd.merge(locs_kai, locs_gov, how='outer',\
                on=['Monitor ID', 'Latitude', 'Longitude', 'Location', 'Type'], copy=False)
data_kai = pd.read_csv(filepath_data_kai, index_col=[0,1], parse_dates=True)[sensor]
data_gov = pd.read_csv(filepath_data_gov, index_col=[0,1], parse_dates=True)[sensor]
data = pd.concat([data_kai, data_gov], axis=0, copy=False)
data.replace(0,np.nan,inplace=True)

start_dt = data.index.levels[1][0]
end_dt = data.index.levels[1][-1]

if start_dt.tzname != 'IST':
        if start_dt.tzinfo is None:
            start_dt = start_dt.tz_localize('UTC')
        start_dt = start_dt.tz_convert(pytz.FixedOffset(330))
    
if end_dt.tzname != 'IST':
    if end_dt.tzinfo is None: 
        end_dt = end_dt.tz_localize('UTC')
    end_dt = end_dt.tz_convert(pytz.FixedOffset(330))

# now, filter through the start and end dates
data.sort_index(inplace=True)
data = data.loc[(slice(None), slice(start_dt, end_dt))]

if(source=='govdata'):
    df = data_gov.unstack(level=0)
elif(source=='kaiterra'):
    df = data_kai.unstack(level=0)
else:
    df = data.unstack(level=0)
distances = pd.read_csv('/scratch/ab9738/pollution_with_sensors/data/combined_distances.csv', index_col=[0])
distances = distances.loc[df.columns, df.columns]
distances[distances == 0] = np.nan

# %%
df = np.log(df)

# %%
locs
# Out:
#                                                    UDID   Latitude  Longitude  \
# Monitor ID
# BB4A                   492457f434f94afc865bb4701990bb4a  28.554980  77.194430
# 91B8                   ea3ceeefd9654dfd9aab41422f7391b8  28.503050  77.185660
# BC46                   29b8262425cf4135899cd65b2458bc46  28.632950  77.288700
# BFDC                   11047d2ddc514f63a12ad4f1ad3bbfdc  28.521083  77.214237
# D804                   f083e8afd43e4727a5eb7f3a1529d804  28.558230  77.208620
# ...                                                 ...        ...        ...
# Sirifort_CPCB                                       NaN  28.550425  77.215938
# SoniaVihar_DPCC                                     NaN  28.710508  77.249485
# SriAurobindoMarg_DPCC                               NaN  28.531346  77.190156
# VivekVihar_DPCC                                     NaN  28.672342  77.315260
# Wazirpur_DPCC                                       NaN  28.699793  77.165453
#
#                             Address                          Location  \
# Monitor ID
# BB4A                          Jamun                 Hauz Khas Village
# 91B8                         Vihara                         Chhatapur
# BC46                   Segel Design                       Preet Vihar
# BFDC                      Arundhati                             Saket
# D804                           EPoD                       Yusuf Sarai
# ...                             ...                               ...
# Sirifort_CPCB                   NaN        Sirifort, New Delhi - CPCB
# SoniaVihar_DPCC                 NaN         Sonia Vihar, Delhi - DPCC
# SriAurobindoMarg_DPCC           NaN  Sri Aurobindo Marg, Delhi - DPCC
# VivekVihar_DPCC                 NaN         Vivek Vihar, Delhi - DPCC
# Wazirpur_DPCC                   NaN            Wazirpur, Delhi - DPCC
#
#                            Type
# Monitor ID
# BB4A                   Kaiterra
# 91B8                   Kaiterra
# BC46                   Kaiterra
# BFDC                   Kaiterra
# D804                   Kaiterra
# ...                         ...
# Sirifort_CPCB              Govt
# SoniaVihar_DPCC            Govt
# SriAurobindoMarg_DPCC      Govt
# VivekVihar_DPCC            Govt
# Wazirpur_DPCC              Govt
#
# [62 rows x 6 columns]

# %% [markdown]
# Spline correction

# %%
sens = np.log(data).to_frame().reset_index()

sens['hour_of_day'] = sens['timestamp_round'].apply(lambda x: x.hour)

spline = sens.groupby(['field_egg_id', 'hour_of_day']).mean()['pm25'].reset_index()
spline_avg = sens.groupby(['hour_of_day']).mean()['pm25'].reset_index()

fields = []
times = []
pm25 = []
for i in np.unique(spline['field_egg_id']):
    s_i = spline[spline['field_egg_id']==i]
    x = s_i['hour_of_day'].values
    y = [t for t in s_i['pm25'].values]
    c1 = CubicSpline(x[:8],y[:8])
    c2 = CubicSpline(x[8:16],y[8:16])
    c3 = CubicSpline(x[16:24],y[16:24])
    ix = [k/100.0 for k in range(2400)]
    iy = list(np.concatenate((c1(ix[:800]),c2(ix[800:1600]),c3(ix[1600:2400]))))
    fields += [i]*2400
    times += ix
    pm25 += iy

spline_df = pd.DataFrame((fields, times, pm25)).transpose()

spline_df.columns = ['field_egg_id', 'time', 'pm25']

hours_in_day = np.arange(24).astype(float)

spline_df = spline_df[spline_df['time'].isin(hours_in_day)]

spline_mat = np.transpose(spline_df['pm25'].to_numpy().reshape((60,24))).astype(float)

spline_df = pd.DataFrame(spline_mat,columns=df.columns)
df_full = deepcopy(df)
for idx,row in df.iterrows():
    df.loc[idx] = row-spline_df.loc[idx.hour]
df_spline = df_full-df

# %% [markdown]
# Data Spliting

# %%
x_tr, x_ts, y_tr, y_ts, spl_tr, spl_ts = [], [], [], [], [], []
for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
    lat = locs.loc[df.columns]['Longitude'].values
    long = locs.loc[df.columns]['Latitude'].values
    val = row.values
    
    cols = np.array(df.columns)[~np.isnan(val)]
    lat = lat[~np.isnan(val)]
    long = long[~np.isnan(val)]
    val = val[~np.isnan(val)]
    
    t = (idx-df.index[0]).total_seconds()

    if(len(val)<30):
        continue
        
    x = np.array([[la,lo,t] for la, lo in zip(lat, long)])
    y = np.array(val)
    y = np.expand_dims(y, 1)
    
    x_train, x_test, y_train, y_test, cols_train, cols_test = train_test_split(
        x, y, cols, test_size=0.2, random_state=42
    )
    
    spl_train = spline_df.loc[idx.hour][cols_train].values
    spl_train = np.expand_dims(np.array(spl_train),1)
    spl_test = spline_df.loc[idx.hour][cols_test].values
    spl_test = np.expand_dims(np.array(spl_test),1)
    
    x_tr.append(x_train)
    x_ts.append(x_test)
    y_tr.append(y_train)
    y_ts.append(y_test)
    spl_tr.append(spl_train)
    spl_ts.append(spl_test)
# Out:
# 100%|██████████| 21960/21960 [00:41<00:00, 533.51it/s]

# %% [markdown]
# Spatial Kriging

# %%
ape = []
for i in tqdm(range(len(x_tr))):
    x_train, x_test, y_train, y_test, spl_train, spl_test = x_tr[i], x_ts[i], y_tr[i], y_ts[i], spl_tr[i], spl_ts[i]
    gp = gpflow.models.GPR((x_train[:,:2].astype(np.float64), y_train),kernel=gpflow.kernels.Linear(),)
    pred, _ = gp.predict_f(x_test[:,:2].astype(np.float64))
    ape.append(np.abs((np.exp(y_test+spl_test)-np.exp(pred+spl_test))/np.exp(y_test+spl_test)))
ape_arr = np.concatenate(ape)
mape = np.mean(ape_arr)
mape
# Out:
#   0%|          | 0/20575 [00:00<?, ?it/s]
# 0.22020828098756168

# %% [markdown]
# Space-Time

# %%
ape = []
ws = 50
for i in tqdm(range(ws,len(x_tr[ws:-ws]))):
    x_train, x_test, y_train, y_test, spl_train, spl_test = x_tr[i-ws:i+ws], x_ts[i], y_tr[i-ws:i+ws], y_ts[i],\
    spl_tr[i-ws:i+ws], spl_ts[i]
    x_train = x_train+x_ts[i-ws:i]+x_ts[i+1:i+ws]
    y_train = y_train+y_ts[i-ws:i]+y_ts[i+1:i+ws]
    x_train = np.concatenate(x_train)
    y_train = np.concatenate(y_train)
    
    k_space = gpflow.kernels.SquaredExponential(active_dims=[0,1])
    k_time = gpflow.kernels.SquaredExponential(active_dims=[2])
    k_spacetime = gpflow.kernels.SquaredExponential(active_dims=[0,1])*k_time
    
    gp = gpflow.models.GPR((x_train.astype(np.float64), y_train),kernel=k_space+k_time+k_spacetime)
    
    pred, _ = gp.predict_f(x_test.astype(np.float64))
    
    ape.append(np.abs((np.exp(y_test+spl_test)-np.exp(pred+spl_test))/np.exp(y_test+spl_test)))
    
ape_arr = np.concatenate(ape)
mape = np.mean(ape_arr)
mape
# Out:
#   0%|          | 9/20425 [00:10<6:52:42,  1.21s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [91], in <cell line: 3>()
#      12 k_time = gpflow.kernels.SquaredExponential(active_dims=[2])
#      13 k_spacetime = gpflow.kernels.SquaredExponential(active_dims=[0,1])*k_time
# ---> 15 gp = gpflow.models.GPR((x_train.astype(np.float64), y_train),kernel=k_space+k_time+k_spacetime)
#      17 pred, _ = gp.predict_f(x_test.astype(np.float64))
#      19 ape.append(np.abs((np.exp(y_test+spl_test)-np.exp(pred+spl_test))/np.exp(y_test+spl_test)))
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/check_shapes/integration/tf.py:76, in install_tf_integration.<locals>.TfWrapperPostProcessor.on_wrap.<locals>.wrapped_method(self, *args, **kwargs)
#      75 def wrapped_method(self: Any, *args: Any, **kwargs: Any) -> Any:
# ---> 76     return wrapped_function(self, *args, **kwargs)
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/check_shapes/decorator.py:192, in check_shapes.<locals>._check_shapes.<locals>.wrapped_function(*args, **kwargs)
#     190 with set_shape_checker(checker):
#     191     try:
# --> 192         result = func(*args, **kwargs)
#     193     except Exception:
#     194         drop_stack_frame()
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/gpflow/models/gpr.py:78, in GPR_deprecated.__init__(self, data, kernel, mean_function, noise_variance, likelihood)
#      76     if noise_variance is None:
#      77         noise_variance = 1.0
# ---> 78     likelihood = gpflow.likelihoods.Gaussian(noise_variance)
#      79 _, Y_data = data
#      80 super().__init__(kernel, likelihood, mean_function, num_latent_gps=Y_data.shape[-1])
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/gpflow/likelihoods/scalar_continuous.py:75, in Gaussian.__init__(self, variance, scale, variance_lower_bound, **kwargs)
#      73     if variance is None:
#      74         variance = 1.0
# ---> 75     self.variance: Optional[ParameterOrFunction] = prepare_parameter_or_function(
#      76         variance, lower_bound=self.variance_lower_bound
#      77     )
#      78     self.scale: Optional[ParameterOrFunction] = None
#      79 else:
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/gpflow/utilities/parameter_or_function.py:38, in prepare_parameter_or_function(value, lower_bound)
#      36     return Parameter(value)
#      37 else:
# ---> 38     return Parameter(value, transform=positive(lower_bound))
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/gpflow/base.py:175, in Parameter.__init__(self, value, transform, prior, prior_on, trainable, dtype, name, unconstrained_shape, constrained_shape, shape)
#     171     trainable = trainable if trainable is not None else True
#     173     tensor_value = _cast_to_dtype(value, dtype)
# --> 175 _validate_unconstrained_value(tensor_value, transform, dtype)
#     177 if shape is not None:
#     178     assert unconstrained_shape is None, "Cannot set both `shape` and `unconstrained_shape`."
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/gpflow/base.py:318, in _validate_unconstrained_value(value, transform, dtype)
#     314 def _validate_unconstrained_value(
#     315     value: TensorData, transform: tfp.bijectors.Bijector, dtype: DType
#     316 ) -> tf.Tensor:
#     317     value = _cast_to_dtype(value, dtype)
# --> 318     unconstrained_value = _to_unconstrained(value, transform)
#     319     if unconstrained_value.dtype.is_integer:
#     320         return unconstrained_value
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/gpflow/base.py:337, in _to_unconstrained(value, transform)
#     335 def _to_unconstrained(value: TensorType, transform: Optional[Transform]) -> TensorType:
#     336     if transform is not None:
# --> 337         return transform.inverse(value)
#     338     return value
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/tensorflow_probability/python/bijectors/bijector.py:1389, in Bijector.inverse(self, y, name, **kwargs)
#    1371 def inverse(self, y, name='inverse', **kwargs):
#    1372   """Returns the inverse `Bijector` evaluation, i.e., X = g^{-1}(Y).
#    1373
#    1374   Args:
#    (...)
#    1387     NotImplementedError: if `_inverse` is not implemented.
#    1388   """
# -> 1389   return self._call_inverse(y, name, **kwargs)
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/tensorflow_probability/python/bijectors/bijector.py:1369, in Bijector._call_inverse(self, y, name, **kwargs)
#    1367 if not self._is_injective:  # No caching for non-injective
#    1368   return self._inverse(y, **kwargs)
# -> 1369 return self._cache.inverse(y, **kwargs)
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/tensorflow_probability/python/internal/cache_util.py:347, in BijectorCache.inverse(self, y, **kwargs)
#     336 def inverse(self, y, **kwargs):
#     337   """Invokes the 'inverse' transformation, or looks up previous results.
#     338
#     339   Args:
#    (...)
#     345     The output of the bijector's `_inverse` method, or a cached result.
#     346   """
# --> 347   return self._lookup(y, self._inverse_name, self._forward_name, **kwargs)
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/tensorflow_probability/python/internal/cache_util.py:494, in BijectorCache._lookup(self, input, forward_name, inverse_name, **kwargs)
#     488 else:
#     489   # Get the output structure, and declare a
#     490   # weakref to clear it from the cache once it gets GCed
#     491   output = nest.map_structure(
#     492       _containerize,
#     493       self._invoke(input, forward_name, kwargs, attrs))
# --> 494   output_ref = WeakStructRef(
#     495       output,
#     496       subkey=(self.bijector, self.bijector_class, inverse_name, kwargs),
#     497       callback=self.storage.maybe_del)
#     498   # Set the input->output mapping.
#     499   self.storage[input_ref] = _DirectedFunctionInvocation(
#     500       input_ref, output_ref, attributes=attrs, dependencies=None)
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/tensorflow_probability/python/internal/cache_util.py:137, in WeakStructRef.__init__(self, struct, subkey, callback)
#     133 self._subkey = nest.map_structure((lambda x: x), subkey)
#     134 # Because `struct` and `subkey` are both immutable containers,
#     135 # we assume that their hashes are stable and unchanging.
#     136 # Compute the hash and store it with the object.
# --> 137 self._hash = hash(hashable_structure((self._struct, self._subkey)))
#     138 self._callback = callback
#     139 self._alive = True
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/tensorflow_probability/python/bijectors/bijector.py:780, in Bijector.__hash__(self)
#     779 def __hash__(self):
# --> 780   return hash(cache_util.hashable_structure((
#     781       type(self), self._get_parameterization())))
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/tensorflow_probability/python/bijectors/bijector.py:780, in Bijector.__hash__(self)
#     779 def __hash__(self):
# --> 780   return hash(cache_util.hashable_structure((
#     781       type(self), self._get_parameterization())))
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/tensorflow_probability/python/internal/cache_util.py:49, in hashable_structure(struct)
#      47     return ObjectIdentityWrapper(obj)
#      48 # Flatten structs into a tuple of tuples to make mutable containers hashable.
# ---> 49 return tuple((k, make_hashable(v))
#      50              for k, v in nest.flatten_with_tuple_paths(struct))
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/tensorflow_probability/python/internal/cache_util.py:49, in <genexpr>(.0)
#      47     return ObjectIdentityWrapper(obj)
#      48 # Flatten structs into a tuple of tuples to make mutable containers hashable.
# ---> 49 return tuple((k, make_hashable(v))
#      50              for k, v in nest.flatten_with_tuple_paths(struct))
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/tensorflow_probability/python/internal/cache_util.py:41, in hashable_structure.<locals>.make_hashable(obj)
#      39   obj_hash = hash(str(obj.__array_interface__) + str(id(obj)))
#      40   return ObjectIdentityWrapper(obj, object_hash=obj_hash)
# ---> 41 elif tf.is_tensor(obj):
#      42   return ObjectIdentityWrapper(obj)
#      43 try:
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/site-packages/tensorflow/python/framework/tensor_util.py:1139, in is_tf_type(x)
#    1111 @tf_export("is_tensor")
#    1112 def is_tf_type(x):  # pylint: disable=invalid-name
#    1113   """Checks whether `x` is a TF-native type that can be passed to many TF ops.
#    1114
#    1115   Use `is_tensor` to differentiate types that can ingested by TensorFlow ops
#    (...)
#    1137     `True` if `x` is a TensorFlow-native type.
#    1138   """
# -> 1139   return isinstance(x, tf_type_classes)
#
# File /scratch/ab9738/cctv_pollution/env/lib/python3.10/typing.py:1477, in _ProtocolMeta.__instancecheck__(cls, instance)
#    1475     return True
#    1476 if cls._is_protocol:
# -> 1477     if all(hasattr(instance, attr) and
#    1478             # All *methods* can be blocked by setting them to None.
#    1479             (not callable(getattr(cls, attr, None)) or
#    1480              getattr(instance, attr) is not None)
#    1481             for attr in _get_protocol_attrs(cls)):
#    1482         return True
#    1483 return super().__instancecheck__(instance)
#
# KeyboardInterrupt:
